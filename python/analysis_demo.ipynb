# %%
import torch
import torch_directml
import pandas as pd
import numpy as np

print(f"PyTorch version: {torch.__version__}")
# Out:
# PyTorch version: 2.4.1+cpu

# %%
# Check for DirectML device
dml = torch_directml.device()
print(f"DirectML Device: {dml}")

# Create a tensor on the AMD GPU
x = torch.tensor([1.0, 2.0, 3.0], device=dml)
print(f"Tensor on GPU: {x}")
# Out:
# DirectML Device: privateuseone:0
# Tensor on GPU: tensor([1., 2., 3.], device='privateuseone:0')

# %%
# Dummy Data Loading (Replace with actual data loading logic)
# df = pd.read_csv('../data/BTCUSDT-trades-2024-01.csv')
# print(df.head())
